# %% [markdown]
# # Mi cuaderno
# ## (feb 3)

# %% [markdown]
# Yulieth P Panqueva Avellaneda
# Ingeniería ambiental
# Universidad Central

# %%
# Realizar operaciones básicas
"1"+"1"
# Out:
# '11'

# %%
6*5
# Out:
# 30

# %% [markdown]
# Métodos numéricos es un tema relacionado con los avances tecnológicos, donde podemos ver que películas estrenadas hace más de dos decadas cuentan e interpretan las posibilidades del futuro, en las cuales se e la interacción humano-robot, haciendo suposiciones de lo que podría generar esto, donde el robot se va asemejando más a las condiciones de un humano.

# %% [markdown]
# Durante la clase se pudieron mencionar algunos ejemplos de éstas películas, como:
# A.I Inteligencia artificial del director Steven Spielberg donde un niño robot crea un vínculo con las personas generando características emocionales como las de un ser humano. Esta película logra dejar la incertidumbre sobre lo que pasaría con los avances tecnológicos y el papel del ser humano con relación al razonamiento de los robots.

# %% [markdown]
# ![imagen 1](https://adopcionpuntodeencuentro.com/web/wp-content/uploads/ai.jpg)

# %% [markdown]
# Historias como la de Alan Turing, un matemático Británico que logra desigrar los códigos nazis para darle fin a la Segunda Guerra Mundial, dando así teorías para la computación moderna. Está parte tan importante se puede ver reflejada en la película dirigida por Morten Tyldum y estrenada en el año 2014 donde el actor Benedict Cumberbatch interpreta a Turing.
# Con el logro de Turing se logra que la guerra no se extienda por más tiempo.

# %% [markdown]
# ![imagen 2](https://www.biografiasyvidas.com/biografia/t/fotos/turing.jpg)

# %% [markdown]
# Otro hecho importante para los avances de la computación ocurrió en 1996 cuando se desarrolló un juego de ajedrez entre Deep Blue, un supercomputador desarrollado por IBM, y el profesional ajedrecista Garry Kasparov donde este profesional fue derrotado por la máquina.

# %% [markdown]
# ![imagen 3](https://3.bp.blogspot.com/-223X-nzmlmA/WiBGKCaYzdI/AAAAAAACMRQ/7sSlSFcetEwUL3jti_04OJiqHZ225GU-wCEwYBhgL/s320/garry%2Bkasparov.webp)

# %% [markdown]
# En la presentación de la clase cabe resaltar la importancia del señor Elon Musk cofundador de empresas como Tesla Motors, SpaceX, OpenAI entre otras.
# OpenAI es una empresa que se dedica a la investigación de inteligencia artificial, donde rezaltan proyectos como la elaboración de un juego en el que participan computadores o la mano robótica que resuelve un cubo rubik

# %%
# import IPython.display.YouTubeVideo class.
from IPython.display import YouTubeVideo
# create an instance of YouTubeVideo class with provided youtube video id.
youtube_video = YouTubeVideo('x4O8pojMF0w')
# display youtube video
display(youtube_video)

# %% [markdown]
# De esta forma damos inicio a la materia donde por medio de Anaconda realizaremos las actividades respectivas.

# %% [markdown]
# ## (Feb 12)

# %% [markdown]
# Durante la clase se mencionó la existencia de los números pseudoaleatorios; estos números según información web, "Los números pseudo aleatorios son números generados en un proceso que parece producir números al azar, pero no lo hace realmente, de aquí el prefijo pseudo que quiere decir falso, ya que su generación parte de algoritmos determinísticos, lo cual nos quiere decir que obtendremos siempre el mismo resultado bajo las mismas condiciones iniciales. Estas condiciones se refieren a varios parámetros de arranque, siendo el valor inicial, también llamado semilla, el denominador común de todos los algoritmos." \
# Tomado de: https://es.slideshare.net/albertojeca/numeros-pseudoaleatorios-y-variables-aleatorias

# %% [markdown]
# George Boole fue un matemático, considerado uno de los padres de las ciencias computacionales por el algebra booleana.
# El álgebra de Boole consiste en la esquematización de enunciados básicos empleando una aritmética binaria. Él mismo resumió su hallazgo en esta sencilla y abstracta frase: "Las interpretaciones respectivas de los símbolos 0 y 1 en el sistema de lógica son Nada y Universo".\
# Tomado de: https://elpais.com/cultura/2015/11/02/actualidad/1446422831_484321.html

# %% [markdown]
# ¿Qué es un fractal?

# %%
# import IPython.display.YouTubeVideo class.
from IPython.display import YouTubeVideo
# create an instance of YouTubeVideo class with provided youtube video id.
youtube_video = YouTubeVideo('Wea_1L-C9Xo')
# display youtube video
display(youtube_video)

# %%
Es un tema aún difícil de entender
