# %% [markdown]
# ## Pre parcial

# %% [markdown]
# ##### Laura Riaño
# ##### Yulieth Panqueva

# %% [markdown]
# ## 1.

# %%
#imagen 1

# %% [markdown]
# #### *¿Alguna de estas versiones generan conflicto?*
# En ninguna de las versiones se generó conflicto
# ####  *¿Son las últimas versiones disponibles en la documentación oficial?*
# Si, todas las versiones utilizadas son las más actuales

# %% [markdown]
# ## 2.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0,9,1)
y = x*np.tan(x)

plt.plot(x,y)
plt.show()
